# %%
# Kết nối COLAB với GDrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Unzip file data.zip
# %cd /content/gdrive/MyDrive/fraud_data
# !unzip fraud_data.zip
# Out:
# /content/gdrive/MyDrive/fraud_data
# Archive:  fraud_data.zip
#   inflating: creditcard.csv

# %%
# Đọc dữ liệu
import pandas as pd
df = pd.read_csv("/content/gdrive/MyDrive/fraud_data/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Đếm số dòng dữ liệu 
df.count()
#  284807 dòng dữ liệu
# Out:
# Time      284807
# V1        284807
# V2        284807
# V3        284807
# V4        284807
# V5        284807
# V6        284807
# V7        284807
# V8        284807
# V9        284807
# V10       284807
# V11       284807
# V12       284807
# V13       284807
# V14       284807
# V15       284807
# V16       284807
# V17       284807
# V18       284807
# V19       284807
# V20       284807
# V21       284807
# V22       284807
# V23       284807
# V24       284807
# V25       284807
# V26       284807
# V27       284807
# V28       284807
# Amount    284807
# Class     284807
# dtype: int64

# %%
# Số dòng dữ liệu mỗi class
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# - Việc sử dụng classification thông thường để train model không hiệu quả.
# - Vì Fraud và Normal chênh lệch khá cao.

# %% [markdown]
# **Train model Auto Encoder**

# %% [markdown]
# - Train dữ liệu Normal bằng Encoder
# - f(x) ~= x: có nghĩa là khi đưa dữ liệu gì vào trả ra dữ liệu đó (Input ~= Output)

# %%
# Drop cột time
df_no_time = df.drop(columns=['Time'])
df_no_time.head()
# Out:
#          V1        V2        V3        V4  ...       V27       V28  Amount  Class
# 0 -1.359807 -0.072781  2.536347  1.378155  ...  0.133558 -0.021053  149.62      0
# 1  1.191857  0.266151  0.166480  0.448154  ... -0.008983  0.014724    2.69      0
# 2 -1.358354 -1.340163  1.773209  0.379780  ... -0.055353 -0.059752  378.66      0
# 3 -0.966272 -0.185226  1.792993 -0.863291  ...  0.062723  0.061458  123.50      0
# 4 -1.158233  0.877737  1.548718  0.403034  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 30 columns]

# %%
# Chuẩn hóa dữ liệu cột Amount
from sklearn.preprocessing import StandardScaler

df_no_time ['Amount'] = StandardScaler().fit_transform(df_no_time['Amount'].values.reshape(-1,1))

# %%
df_no_time.head()
# Out:
#          V1        V2        V3        V4  ...       V27       V28    Amount  Class
# 0 -1.359807 -0.072781  2.536347  1.378155  ...  0.133558 -0.021053  0.244964      0
# 1  1.191857  0.266151  0.166480  0.448154  ... -0.008983  0.014724 -0.342475      0
# 2 -1.358354 -1.340163  1.773209  0.379780  ... -0.055353 -0.059752  1.160686      0
# 3 -0.966272 -0.185226  1.792993 -0.863291  ...  0.062723  0.061458  0.140534      0
# 4 -1.158233  0.877737  1.548718  0.403034  ...  0.219422  0.215153 -0.073403      0
#
# [5 rows x 30 columns]

# %%
# Phân chia dữ liệu train test
from sklearn.model_selection import train_test_split

x_train, x_test = train_test_split(df_no_time, test_size=0.2, random_state=42)

# Điều chế dữ liệu train
x_train = x_train[x_train['Class']==0]
x_train = x_train.drop(columns=['Class'])

# Điều chế x_test
y_test = x_test['Class']
x_test = x_test.drop(columns=['Class']) 

x_train = x_train.values
x_test = x_test.values

# %%
# Kiểm tra dữ liệu train test
print(x_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (227451, 29)
# (56962, 29)
# (56962,)

# %%
# Build Model 
from keras.layers import Input, Dense
from keras.models import load_model, Model
from keras.callbacks import ModelCheckpoint

# Xây dựng model
input_dimension = x_train.shape[1]
hidden_size = 128

input_layer = Input(shape=(input_dimension,))

# Encoder
encoder = Dense(hidden_size, activation = "relu") (input_layer)
encoder = Dense(hidden_size //2, activation="relu") (encoder)
encoder = Dense(hidden_size //4, activation="relu") (encoder)

# Decoder
decoder = Dense(hidden_size //4, activation="relu") (encoder)
decoder = Dense(hidden_size //2, activation="relu") (decoder)
decoder = Dense(hidden_size, activation = "relu") (decoder)

# Output
output_layer = Dense(input_dimension, activation="relu") (decoder)

auto_encoder_model= Model(inputs = input_layer, outputs = output_layer)
auto_encoder_model.compile (optimizer ="adam", loss="mse", metrics=['accuracy'])
auto_encoder_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 29)]              0
#
#  dense_7 (Dense)             (None, 128)               3840
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  dense_10 (Dense)            (None, 32)                1056
#
#  dense_11 (Dense)            (None, 64)                2112
#
#  dense_12 (Dense)            (None, 128)               8320
#
#  dense_13 (Dense)            (None, 29)                3741
#
# =================================================================
# Total params: 29,405
# Trainable params: 29,405
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - Input: 29
# - Output: 29

# %%
# Train model
n_epochs = 50
n_batch_size = 32

save_best = ModelCheckpoint(filepath = "/content/gdrive/MyDrive/fraud_data/best.h5", 
                            monitor='val_loss', verbose=1, save_best_only=True)

history = auto_encoder_model.fit(x_train, x_train, batch_size=n_batch_size, epochs=n_epochs,verbose=1,
                                 shuffle=True, callbacks=[save_best],
                                 validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 7104/7108 [============================>.] - ETA: 0s - loss: 0.8614 - accuracy: 0.3535
# Epoch 1: val_loss improved from inf to 0.88584, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8613 - accuracy: 0.3535 - val_loss: 0.8858 - val_accuracy: 0.3571
# Epoch 2/50
# 7108/7108 [==============================] - ETA: 0s - loss: 0.8613 - accuracy: 0.3533
# Epoch 2: val_loss did not improve from 0.88584
# 7108/7108 [==============================] - 46s 6ms/step - loss: 0.8613 - accuracy: 0.3533 - val_loss: 0.8860 - val_accuracy: 0.3558
# Epoch 3/50
# 7107/7108 [============================>.] - ETA: 0s - loss: 0.8614 - accuracy: 0.3535
# Epoch 3: val_loss did not improve from 0.88584
# 7108/7108 [==============================] - 36s 5ms/step - loss: 0.8613 - accuracy: 0.3535 - val_loss: 0.8860 - val_accuracy: 0.3558
# Epoch 4/50
# 7101/7108 [============================>.] - ETA: 0s - loss: 0.8606 - accuracy: 0.3532
# Epoch 4: val_loss did not improve from 0.88584
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8613 - accuracy: 0.3532 - val_loss: 0.8859 - val_accuracy: 0.3569
# Epoch 5/50
# 7098/7108 [============================>.] - ETA: 0s - loss: 0.8612 - accuracy: 0.3535
# Epoch 5: val_loss did not improve from 0.88584
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8613 - accuracy: 0.3534 - val_loss: 0.8859 - val_accuracy: 0.3572
# Epoch 6/50
# 7105/7108 [============================>.] - ETA: 0s - loss: 0.8612 - accuracy: 0.3531
# Epoch 6: val_loss improved from 0.88584 to 0.88584, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8614 - accuracy: 0.3531 - val_loss: 0.8858 - val_accuracy: 0.3578
# Epoch 7/50
# 7107/7108 [============================>.] - ETA: 0s - loss: 0.8614 - accuracy: 0.3532
# Epoch 7: val_loss did not improve from 0.88584
# 7108/7108 [==============================] - 39s 6ms/step - loss: 0.8614 - accuracy: 0.3532 - val_loss: 0.8861 - val_accuracy: 0.3553
# Epoch 8/50
# 7099/7108 [============================>.] - ETA: 0s - loss: 0.8616 - accuracy: 0.3534
# Epoch 8: val_loss did not improve from 0.88584
# 7108/7108 [==============================] - 37s 5ms/step - loss: 0.8614 - accuracy: 0.3534 - val_loss: 0.8858 - val_accuracy: 0.3574
# Epoch 9/50
# 7102/7108 [============================>.] - ETA: 0s - loss: 0.8614 - accuracy: 0.3534
# Epoch 9: val_loss did not improve from 0.88584
# 7108/7108 [==============================] - 44s 6ms/step - loss: 0.8614 - accuracy: 0.3534 - val_loss: 0.8863 - val_accuracy: 0.3544
# Epoch 10/50
# 7105/7108 [============================>.] - ETA: 0s - loss: 0.8614 - accuracy: 0.3528
# Epoch 10: val_loss did not improve from 0.88584
# 7108/7108 [==============================] - 36s 5ms/step - loss: 0.8613 - accuracy: 0.3528 - val_loss: 0.8879 - val_accuracy: 0.3455
# Epoch 11/50
# 7107/7108 [============================>.] - ETA: 0s - loss: 0.8612 - accuracy: 0.3526
# Epoch 11: val_loss improved from 0.88584 to 0.88449, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8612 - accuracy: 0.3526 - val_loss: 0.8845 - val_accuracy: 0.3548
# Epoch 12/50
# 7107/7108 [============================>.] - ETA: 0s - loss: 0.8529 - accuracy: 0.3589
# Epoch 12: val_loss improved from 0.88449 to 0.87463, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 35s 5ms/step - loss: 0.8529 - accuracy: 0.3589 - val_loss: 0.8746 - val_accuracy: 0.3674
# Epoch 13/50
# 7101/7108 [============================>.] - ETA: 0s - loss: 0.8499 - accuracy: 0.3652
# Epoch 13: val_loss improved from 0.87463 to 0.87441, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 35s 5ms/step - loss: 0.8498 - accuracy: 0.3652 - val_loss: 0.8744 - val_accuracy: 0.3686
# Epoch 14/50
# 7101/7108 [============================>.] - ETA: 0s - loss: 0.8496 - accuracy: 0.3649
# Epoch 14: val_loss improved from 0.87441 to 0.87376, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8495 - accuracy: 0.3649 - val_loss: 0.8738 - val_accuracy: 0.3692
# Epoch 15/50
# 7100/7108 [============================>.] - ETA: 0s - loss: 0.8493 - accuracy: 0.3642
# Epoch 15: val_loss improved from 0.87376 to 0.87348, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8493 - accuracy: 0.3642 - val_loss: 0.8735 - val_accuracy: 0.3669
# Epoch 16/50
# 7101/7108 [============================>.] - ETA: 0s - loss: 0.8486 - accuracy: 0.3651
# Epoch 16: val_loss improved from 0.87348 to 0.87335, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8485 - accuracy: 0.3651 - val_loss: 0.8733 - val_accuracy: 0.3665
# Epoch 17/50
# 7107/7108 [============================>.] - ETA: 0s - loss: 0.8482 - accuracy: 0.3658
# Epoch 17: val_loss improved from 0.87335 to 0.87262, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8481 - accuracy: 0.3658 - val_loss: 0.8726 - val_accuracy: 0.3696
# Epoch 18/50
# 7101/7108 [============================>.] - ETA: 0s - loss: 0.8481 - accuracy: 0.3659
# Epoch 18: val_loss improved from 0.87262 to 0.87253, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8482 - accuracy: 0.3659 - val_loss: 0.8725 - val_accuracy: 0.3707
# Epoch 19/50
# 7099/7108 [============================>.] - ETA: 0s - loss: 0.8481 - accuracy: 0.3663
# Epoch 19: val_loss did not improve from 0.87253
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8481 - accuracy: 0.3664 - val_loss: 0.8726 - val_accuracy: 0.3699
# Epoch 20/50
# 7104/7108 [============================>.] - ETA: 0s - loss: 0.8481 - accuracy: 0.3662
# Epoch 20: val_loss did not improve from 0.87253
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8481 - accuracy: 0.3662 - val_loss: 0.8726 - val_accuracy: 0.3706
# Epoch 21/50
# 7107/7108 [============================>.] - ETA: 0s - loss: 0.8481 - accuracy: 0.3665
# Epoch 21: val_loss did not improve from 0.87253
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8480 - accuracy: 0.3664 - val_loss: 0.8726 - val_accuracy: 0.3696
# Epoch 22/50
# 7107/7108 [============================>.] - ETA: 0s - loss: 0.8482 - accuracy: 0.3654
# Epoch 22: val_loss did not improve from 0.87253
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8482 - accuracy: 0.3654 - val_loss: 0.8726 - val_accuracy: 0.3693
# Epoch 23/50
# 7108/7108 [==============================] - ETA: 0s - loss: 0.8479 - accuracy: 0.3668
# Epoch 23: val_loss improved from 0.87253 to 0.87240, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8479 - accuracy: 0.3668 - val_loss: 0.8724 - val_accuracy: 0.3703
# Epoch 24/50
# 7106/7108 [============================>.] - ETA: 0s - loss: 0.8480 - accuracy: 0.3661
# Epoch 24: val_loss did not improve from 0.87240
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8480 - accuracy: 0.3661 - val_loss: 0.8729 - val_accuracy: 0.3681
# Epoch 25/50
# 7104/7108 [============================>.] - ETA: 0s - loss: 0.8480 - accuracy: 0.3672
# Epoch 25: val_loss did not improve from 0.87240
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8479 - accuracy: 0.3671 - val_loss: 0.8724 - val_accuracy: 0.3705
# Epoch 26/50
# 7101/7108 [============================>.] - ETA: 0s - loss: 0.8483 - accuracy: 0.3659
# Epoch 26: val_loss did not improve from 0.87240
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8481 - accuracy: 0.3660 - val_loss: 0.8726 - val_accuracy: 0.3682
# Epoch 27/50
# 7098/7108 [============================>.] - ETA: 0s - loss: 0.8481 - accuracy: 0.3666
# Epoch 27: val_loss did not improve from 0.87240
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8479 - accuracy: 0.3666 - val_loss: 0.8730 - val_accuracy: 0.3665
# Epoch 28/50
# 7100/7108 [============================>.] - ETA: 0s - loss: 0.8482 - accuracy: 0.3665
# Epoch 28: val_loss did not improve from 0.87240
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8480 - accuracy: 0.3665 - val_loss: 0.8779 - val_accuracy: 0.3511
# Epoch 29/50
# 7106/7108 [============================>.] - ETA: 0s - loss: 0.8480 - accuracy: 0.3668
# Epoch 29: val_loss did not improve from 0.87240
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8479 - accuracy: 0.3667 - val_loss: 0.8729 - val_accuracy: 0.3659
# Epoch 30/50
# 7101/7108 [============================>.] - ETA: 0s - loss: 0.8479 - accuracy: 0.3668
# Epoch 30: val_loss did not improve from 0.87240
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8479 - accuracy: 0.3668 - val_loss: 0.8725 - val_accuracy: 0.3702
# Epoch 31/50
# 7107/7108 [============================>.] - ETA: 0s - loss: 0.8480 - accuracy: 0.3670
# Epoch 31: val_loss improved from 0.87240 to 0.87236, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8479 - accuracy: 0.3670 - val_loss: 0.8724 - val_accuracy: 0.3714
# Epoch 32/50
# 7100/7108 [============================>.] - ETA: 0s - loss: 0.8478 - accuracy: 0.3661
# Epoch 32: val_loss improved from 0.87236 to 0.87199, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8478 - accuracy: 0.3661 - val_loss: 0.8720 - val_accuracy: 0.3688
# Epoch 33/50
# 7105/7108 [============================>.] - ETA: 0s - loss: 0.8474 - accuracy: 0.3646
# Epoch 33: val_loss improved from 0.87199 to 0.87153, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8474 - accuracy: 0.3646 - val_loss: 0.8715 - val_accuracy: 0.3695
# Epoch 34/50
# 7107/7108 [============================>.] - ETA: 0s - loss: 0.8469 - accuracy: 0.3657
# Epoch 34: val_loss improved from 0.87153 to 0.87151, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 35s 5ms/step - loss: 0.8470 - accuracy: 0.3657 - val_loss: 0.8715 - val_accuracy: 0.3703
# Epoch 35/50
# 7103/7108 [============================>.] - ETA: 0s - loss: 0.8468 - accuracy: 0.3657
# Epoch 35: val_loss improved from 0.87151 to 0.87144, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 35s 5ms/step - loss: 0.8469 - accuracy: 0.3658 - val_loss: 0.8714 - val_accuracy: 0.3694
# Epoch 36/50
# 7106/7108 [============================>.] - ETA: 0s - loss: 0.8470 - accuracy: 0.3655
# Epoch 36: val_loss did not improve from 0.87144
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8470 - accuracy: 0.3655 - val_loss: 0.8729 - val_accuracy: 0.3595
# Epoch 37/50
# 7105/7108 [============================>.] - ETA: 0s - loss: 0.8249 - accuracy: 0.4041
# Epoch 37: val_loss improved from 0.87144 to 0.84432, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8248 - accuracy: 0.4041 - val_loss: 0.8443 - val_accuracy: 0.4082
# Epoch 38/50
# 7102/7108 [============================>.] - ETA: 0s - loss: 0.8149 - accuracy: 0.4209
# Epoch 38: val_loss improved from 0.84432 to 0.83843, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8147 - accuracy: 0.4209 - val_loss: 0.8384 - val_accuracy: 0.4260
# Epoch 39/50
# 7107/7108 [============================>.] - ETA: 0s - loss: 0.8128 - accuracy: 0.4230
# Epoch 39: val_loss did not improve from 0.83843
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8127 - accuracy: 0.4230 - val_loss: 0.8393 - val_accuracy: 0.4197
# Epoch 40/50
# 7107/7108 [============================>.] - ETA: 0s - loss: 0.8100 - accuracy: 0.4238
# Epoch 40: val_loss improved from 0.83843 to 0.83211, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8100 - accuracy: 0.4238 - val_loss: 0.8321 - val_accuracy: 0.4285
# Epoch 41/50
# 7099/7108 [============================>.] - ETA: 0s - loss: 0.8084 - accuracy: 0.4249
# Epoch 41: val_loss improved from 0.83211 to 0.82976, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8081 - accuracy: 0.4249 - val_loss: 0.8298 - val_accuracy: 0.4286
# Epoch 42/50
# 7108/7108 [==============================] - ETA: 0s - loss: 0.8058 - accuracy: 0.4278
# Epoch 42: val_loss improved from 0.82976 to 0.82773, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8058 - accuracy: 0.4278 - val_loss: 0.8277 - val_accuracy: 0.4299
# Epoch 43/50
# 7105/7108 [============================>.] - ETA: 0s - loss: 0.8033 - accuracy: 0.4309
# Epoch 43: val_loss improved from 0.82773 to 0.82592, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8033 - accuracy: 0.4309 - val_loss: 0.8259 - val_accuracy: 0.4340
# Epoch 44/50
# 7100/7108 [============================>.] - ETA: 0s - loss: 0.8025 - accuracy: 0.4323
# Epoch 44: val_loss improved from 0.82592 to 0.82451, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8023 - accuracy: 0.4323 - val_loss: 0.8245 - val_accuracy: 0.4355
# Epoch 45/50
# 7101/7108 [============================>.] - ETA: 0s - loss: 0.8005 - accuracy: 0.4346
# Epoch 45: val_loss did not improve from 0.82451
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.8013 - accuracy: 0.4345 - val_loss: 0.8249 - val_accuracy: 0.4382
# Epoch 46/50
# 7104/7108 [============================>.] - ETA: 0s - loss: 0.8010 - accuracy: 0.4349
# Epoch 46: val_loss improved from 0.82451 to 0.82343, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8009 - accuracy: 0.4349 - val_loss: 0.8234 - val_accuracy: 0.4386
# Epoch 47/50
# 7098/7108 [============================>.] - ETA: 0s - loss: 0.8008 - accuracy: 0.4352
# Epoch 47: val_loss did not improve from 0.82343
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8007 - accuracy: 0.4352 - val_loss: 0.8246 - val_accuracy: 0.4295
# Epoch 48/50
# 7102/7108 [============================>.] - ETA: 0s - loss: 0.8001 - accuracy: 0.4357
# Epoch 48: val_loss improved from 0.82343 to 0.82237, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8001 - accuracy: 0.4357 - val_loss: 0.8224 - val_accuracy: 0.4387
# Epoch 49/50
# 7102/7108 [============================>.] - ETA: 0s - loss: 0.8002 - accuracy: 0.4365
# Epoch 49: val_loss improved from 0.82237 to 0.82222, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 34s 5ms/step - loss: 0.8000 - accuracy: 0.4365 - val_loss: 0.8222 - val_accuracy: 0.4398
# Epoch 50/50
# 7104/7108 [============================>.] - ETA: 0s - loss: 0.7997 - accuracy: 0.4366
# Epoch 50: val_loss improved from 0.82222 to 0.82196, saving model to /content/gdrive/MyDrive/fraud_data/best.h5
# 7108/7108 [==============================] - 35s 5ms/step - loss: 0.7996 - accuracy: 0.4365 - val_loss: 0.8220 - val_accuracy: 0.4397

# %%
# In history

import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend()

plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Kiểm tra việc tái tạo trong tập test
import numpy as np

# Dự đoán
predicts = auto_encoder_model.predict(x_test)
mse = np.mean(np.power(x_test - predicts,2), axis=1)
err_df = pd.DataFrame({'error': mse, 'truth': y_test})

# %%
# In ra histogram của error khi tái tạo các điểm Normal trong tập test
normal_error_df = err_df[(err_df['truth']==0) & (err_df['error'] < 10)]

_ = plt.hist(normal_error_df.error.values, bins= 50)

# %% [markdown]
# - Các lỗi error khi tái tạo các điểm Normal phân phối nhiều nhất từ 0 - 2.3
# - Các điểm Normal dùng để train model, tái tạo sẽ có error rất thấp

# %%
# In ra histogram của error khi tái tạo các điểm Fraud (các điểm dữ liệu không được train) trong tập test
fraud_error_df = err_df[(err_df['truth']==1)]
_ = plt.hist(fraud_error_df.error.values, bins= 100)

# %%
# Vẽ ra confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Ngưỡng để phân biệt Fraud (2.3 của Normal)
threshold = 2.3

# y dự đoán
y_pred = [1 if e > threshold else 0 for e in err_df.error.values]
conf_matrix = confusion_matrix(err_df.truth, y_pred)

# Vẽ
sns.heatmap(conf_matrix, xticklabels=["Normal", "Fraud"], yticklabels=['Normal','Fraud'], annot=True, fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predited Values")
plt.ylabel("Truth")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# - Có 54935 điểm dữ liệu Normal được nhận là Normal.
# - Có 1929 điểm dữ liệu Normal được nhận là Fraud (càng giảm càng tốt).
# - Có tổng 98 giao dịch Fraud:
#
#   - 17 điểm dữ liệu nhận nhầm thành Normal.
#   - 81 điểm dữ liệu nhận đúng Fraud.
#
#   20% sai, 80% đúng
#
#   Nhiệm vụ: giảm tối thiểu nhận nhầm Fraud thành Normal và ngược lại.
